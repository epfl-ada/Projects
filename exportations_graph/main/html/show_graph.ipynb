# %%
from IPython.display import IFrame

IFrame(src='honey_graph.html', width=1000, height=600)
# Out:
#         <iframe
#             width="1000"
#             height="600"
#             src="honey_graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
