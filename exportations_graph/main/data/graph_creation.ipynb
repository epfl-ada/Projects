# %%
import pandas as pd

# %%
def json_to_js(json_, name):
    f = open(f"{name}.js", "w+")
    f.write(f"var {name} = ")
    f.write(str(json_))

    f.write(";")

    f.close()

# %%
df = pd.read_csv("Trade_DetailedTradeMatrix_E_All_Data_(Normalized).csv", encoding="latin_1")

# %%
df.head()
# Out:
#    Reporter Country Code Reporter Countries  Partner Country Code  \
# 0                      2        Afghanistan                     4
# 1                      2        Afghanistan                     4
# 2                      2        Afghanistan                     4
# 3                      2        Afghanistan                     4
# 4                      2        Afghanistan                     4
#
#   Partner Countries  Item Code                  Item  Element Code  \
# 0           Algeria        230  Cashew nuts, shelled          5910
# 1           Algeria        230  Cashew nuts, shelled          5922
# 2           Algeria       1293       Crude materials          5922
# 3           Algeria       1293       Crude materials          5922
# 4           Algeria       1293       Crude materials          5922
#
#            Element  Year Code  Year      Unit  Value Flag
# 0  Export Quantity       2016  2016    tonnes    3.0    *
# 1     Export Value       2016  2016  1000 US$   23.0    *
# 2     Export Value       2015  2015  1000 US$    1.0    *
# 3     Export Value       2016  2016  1000 US$    1.0    *
# 4     Export Value       2017  2017  1000 US$    5.0    R

# %%
honey = df[df["Item"] == "Honey, natural"]

# %%
honey = honey[~(honey == 0).any(axis=1)]

# %%
honey = honey[(honey["Unit"] == "tonnes") & (honey["Year"] == 2014) & (honey["Element"] == "Export Quantity")]

# %%
honey.head()
# Out:
#         Reporter Country Code Reporter Countries  Partner Country Code  \
# 13508                       2        Afghanistan                   225
# 213715                      9          Argentina                    10
# 220803                      9          Argentina                   255
# 228370                      9          Argentina                    19
# 254081                      9          Argentina                    33
#
#                        Partner Countries  Item Code            Item  \
# 13508               United Arab Emirates       1182  Honey, natural
# 213715                         Australia       1182  Honey, natural
# 220803                           Belgium       1182  Honey, natural
# 228370  Bolivia (Plurinational State of)       1182  Honey, natural
# 254081                            Canada       1182  Honey, natural
#
#         Element Code          Element  Year Code  Year    Unit   Value Flag
# 13508           5910  Export Quantity       2014  2014  tonnes     1.0    *
# 213715          5910  Export Quantity       2014  2014  tonnes  1061.0  NaN
# 220803          5910  Export Quantity       2014  2014  tonnes    65.0  NaN
# 228370          5910  Export Quantity       2014  2014  tonnes    48.0  NaN
# 254081          5910  Export Quantity       2014  2014  tonnes  1229.0  NaN

# %%
value_country = honey[["Reporter Countries", "Value"]].groupby(["Reporter Countries"]).agg('sum')

# %%
honey[honey["Value"] == honey["Value"].max()]
# Out:
#         Reporter Country Code Reporter Countries  Partner Country Code  \
# 477463                      9          Argentina                   231
#
#                Partner Countries  Item Code            Item  Element Code  \
# 477463  United States of America       1182  Honey, natural          5910
#
#                 Element  Year Code  Year    Unit    Value Flag
# 477463  Export Quantity       2014  2014  tonnes  35911.0  NaN

# %%
value_dict = value_country.to_dict()["Value"]

# %%
honey["Value"].unique()
# Out:
# array([1.0000e+00, 1.0610e+03, 6.5000e+01, 4.8000e+01, 1.2290e+03,
#        9.0000e+01, 3.3800e+02, 6.5840e+03, 1.0810e+03, 8.4000e+01,
#        9.4700e+02, 2.7030e+03, 7.7000e+01, 1.0920e+03, 2.0000e+01,
#        1.5190e+03, 1.9000e+01, 9.5300e+02, 6.7700e+02, 3.5911e+04,
#        3.0000e+00, 2.3000e+01, 3.0000e+01, 4.0100e+02, 3.3100e+02,
#        1.4800e+02, 1.7200e+02, 1.9020e+03, 5.0100e+02, 2.5700e+02,
#        4.4800e+02, 1.1720e+03, 1.5000e+02, 1.1100e+02, 4.5800e+02,
#        1.8500e+02, 5.6500e+02, 3.7140e+03, 1.6200e+02, 4.8030e+03,
#        4.6000e+02, 1.3340e+03, 8.8500e+02, 4.5100e+03, 1.4460e+03,
#        2.0000e+02, 2.4220e+03, 1.9900e+02, 4.0900e+02, 6.0900e+02,
#        3.7400e+02, 1.7830e+03, 1.1472e+04, 7.9900e+02, 6.0800e+02,
#        6.9760e+03, 1.8230e+03, 1.3970e+03, 7.8070e+03, 3.6100e+02,
#        4.1800e+02, 7.2000e+01, 1.1200e+02, 1.2220e+03, 5.1700e+02,
#        5.7500e+02, 4.1600e+02, 2.6900e+02, 6.3100e+02, 1.7600e+02,
#        1.6900e+02, 4.7300e+02, 3.2740e+03, 1.0820e+03, 5.1760e+03,
#        7.9500e+02])

# %%
import json

capitals = json.loads(open('capitals.json').read())
capitals = capitals["features"]
# read file
config = json.loads(open('countries.geo.json').read())
config = config["features"]

# %%
cap_dict = {}
for elem in capitals:
    cap_dict[elem["properties"]["country"]] = elem["geometry"]["coordinates"]

# %%
transforms = {
    "The Bahamas": "Bahamas",
    "Republic of the Congo": "Congo Republic",
    "Democratic Republic of the Congo": "Congo Democratic Republic",
    "Guinea Bissau":"Guinea-Bissau",
    "South Korea": "Korea South",
    "North Korea": "Korea North",
    "Republic of Serbia" : "Serbia",
    "United Republic of Tanzania" : "Tanzania",
    "United States of America" : "United States"     
             }

transforms_pd = {
    "The Bahamas": "Bahamas",
    "Ivory Coast": "Côte d'Ivoire",
    "Republic of Serbia" : "Serbia",
    "Republic of the Congo": "Congo Republic",
    "Democratic Republic of the Congo": "Congo Democratic Republic",
    "Guinea Bissau":"Guinea-Bissau",
    "South Korea": "Republic of Korea",
    "North Korea": "Korea North",
    "Dominican Republic":'Dominica',
    "Russia" : "Russian Federation",
    "Czech Republic": "Czechia",
    "Bolivia" : "Bolivia (Plurinational State of)",
    "China" : "China, mainland",
    "Macedonia" : "North Macedonia",
    "Iran" : "Iran (Islamic Republic of)",
    "East Timor": "Timor-Leste",
    "Taiwan" : "China, Taiwan Province of",
    "Moldova" : "Republic of Moldova",
    "Vietnam": "Viet Nam",
    "Syria":"Syrian Arab Republic",
    "Brunei":"Brunei Darussalam"
             }

inv_transforms_pd = {v: k for k, v in transforms_pd.items()}

def transform(country, transforms):
    return transforms.get(country, country)

# %%
debug = True

# %%
countries = []
existing_country = []
for elem in config:
    country = elem["properties"]["name"]
    existing_country.append(country)
    if (transform(country, transforms) not in cap_dict):
        if debug:
            print(country+" has capital")
        continue
    elif transform(country, transforms_pd) not in value_dict :
        if debug:
            print(country + " not export")
        elem["location"] = cap_dict[transform(country, transforms)]
    else:
        elem["location"] = cap_dict[transform(country, transforms)]
        elem["value"] = value_dict[transform(country, transforms_pd)]
    countries.append(elem)
# Out:
# Angola not export
# Albania not export
# Antarctica not export
# French Southern and Antarctic Lands has capital
# Azerbaijan not export
# Burundi not export
# Burkina Faso not export
# The Bahamas not export
# Belize not export
# Bermuda not export
# Brunei not export
# Bhutan not export
# Botswana not export
# Central African Republic not export
# Democratic Republic of the Congo not export
# Republic of the Congo not export
# Colombia not export
# Costa Rica not export
# Northern Cyprus has capital
# Djibouti not export
# Algeria not export
# Eritrea not export
# Fiji not export
# Falkland Islands not export
# Gabon not export
# Guinea not export
# Gambia not export
# Guinea Bissau not export
# Equatorial Guinea not export
# Greenland not export
# French Guiana has capital
# Honduras not export
# Haiti not export
# Iraq not export
# Iceland not export
# Jamaica not export
# Cambodia not export
# Kosovo has capital
# Laos not export
# Liberia not export
# Libya not export
# Lesotho not export
# Myanmar not export
# Montenegro not export
# Mongolia not export
# Mozambique not export
# Mauritania not export
# Namibia not export
# New Caledonia not export
# Niger not export
# Nigeria not export
# Panama not export
# Philippines not export
# Papua New Guinea not export
# Puerto Rico not export
# North Korea not export
# Paraguay not export
# Rwanda not export
# Western Sahara not export
# Sudan not export
# South Sudan has capital
# Solomon Islands not export
# Sierra Leone not export
# Somaliland has capital
# Somalia not export
# Suriname not export
# Swaziland not export
# Syria not export
# Chad not export
# Togo not export
# Tajikistan not export
# Turkmenistan not export
# East Timor has capital
# Trinidad and Tobago not export
# Uzbekistan not export
# Venezuela not export
# Vietnam not export
# Vanuatu not export
# West Bank has capital
# Zimbabwe not export

# %%
exp = honey[["Reporter Countries", "Partner Countries", "Value"]]
exportations = []
for i in exp.values.tolist():
    if transform(i[0], inv_transforms_pd) in existing_country and transform(i[1], inv_transforms_pd) in existing_country:
        exportations.append({"from":transform(i[0], inv_transforms_pd), "to":transform(i[1], inv_transforms_pd), "Value":i[2],})
    elif debug :
        print (i[0], i[1])
# Out:
# Australia Bahrain
# Australia China, Hong Kong SAR
# Australia Christmas Island
# Australia Maldives
# Australia Mauritius
# Australia Nauru
# Australia Singapore
# Austria Bahrain
# Austria China, Hong Kong SAR
# Austria Maldives
# Austria Singapore
# Bahrain Saudi Arabia
# Belgium China, Hong Kong SAR
# Belgium Maldives
# Belgium Seychelles
# Belgium Singapore
# Bosnia and Herzegovina Unspecified Area
# Brazil China, Hong Kong SAR
# Cabo Verde Netherlands
# Canada Barbados
# Canada China, Hong Kong SAR
# Canada Saint Pierre and Miquelon
# Canada Singapore
# China, Hong Kong SAR China, Macao SAR
# China, Hong Kong SAR China, mainland
# China, Hong Kong SAR China, Taiwan Province of
# China, Hong Kong SAR Republic of Korea
# China, Hong Kong SAR United States of America
# China, Hong Kong SAR Viet Nam
# China, Macao SAR China, Hong Kong SAR
# China, mainland Bahrain
# China, mainland China, Hong Kong SAR
# China, mainland Maldives
# China, mainland Mauritius
# China, mainland Singapore
# China, Taiwan Province of China, Hong Kong SAR
# China, Taiwan Province of China, Macao SAR
# China, Taiwan Province of Singapore
# Côte d'Ivoire Unspecified Area
# Croatia Unspecified Area
# Denmark China, Hong Kong SAR
# Denmark Faroe Islands
# Egypt Bahrain
# Egypt China, Hong Kong SAR
# Egypt Maldives
# Egypt Seychelles
# Eswatini Qatar
# Ethiopia Bahrain
# France Bahrain
# France China, Hong Kong SAR
# France Congo
# France French Polynesia
# France Maldives
# France Mauritius
# France Saint Pierre and Miquelon
# France Seychelles
# France Singapore
# France Unspecified Area
# France Wallis and Futuna Islands
# Georgia China, Hong Kong SAR
# Germany Bahrain
# Germany China, Hong Kong SAR
# Germany Palestine
# Germany Singapore
